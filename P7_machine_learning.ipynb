# %% [markdown]
# <h1>Sommaire<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Previously" data-toc-modified-id="Previously-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Previously</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Settings" data-toc-modified-id="Settings-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Settings</a></span></li><li><span><a href="#Read-data" data-toc-modified-id="Read-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Read data</a></span></li></ul></li><li><span><a href="#Cleaning-dataset" data-toc-modified-id="Cleaning-dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cleaning dataset</a></span><ul class="toc-item"><li><span><a href="#Preparation-for-machine-learning" data-toc-modified-id="Preparation-for-machine-learning-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Preparation for machine learning</a></span></li><li><span><a href="#Train-set-&amp;-test-set" data-toc-modified-id="Train-set-&amp;-test-set-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Train set &amp; test set</a></span></li><li><span><a href="#Re-sampling-train-set-data-with-SMOTE" data-toc-modified-id="Re-sampling-train-set-data-with-SMOTE-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Re-sampling train set data with SMOTE</a></span></li></ul></li><li><span><a href="#Baseline-model-:-Dummy-Classifier" data-toc-modified-id="Baseline-model-:-Dummy-Classifier-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Baseline model : Dummy Classifier</a></span><ul class="toc-item"><li><span><a href="#Model" data-toc-modified-id="Model-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Model</a></span></li><li><span><a href="#Classification-report" data-toc-modified-id="Classification-report-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Classification report</a></span></li><li><span><a href="#ROC-AUC-score" data-toc-modified-id="ROC-AUC-score-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>ROC AUC score</a></span><ul class="toc-item"><li><span><a href="#Train-score" data-toc-modified-id="Train-score-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Train score</a></span></li><li><span><a href="#Test-score" data-toc-modified-id="Test-score-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Test score</a></span></li></ul></li><li><span><a href="#ROC-curve" data-toc-modified-id="ROC-curve-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>ROC curve</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Confusion matrix</a></span></li></ul></li><li><span><a href="#Classification-models-:-first-tests" data-toc-modified-id="Classification-models-:-first-tests-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Classification models : first tests</a></span><ul class="toc-item"><li><span><a href="#Quick-evaluation-function" data-toc-modified-id="Quick-evaluation-function-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Quick evaluation function</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>SGD Classifier</a></span></li><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#XGBoost-Classifier" data-toc-modified-id="XGBoost-Classifier-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>XGBoost Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li></ul></li><li><span><a href="#Pipeline-construction" data-toc-modified-id="Pipeline-construction-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pipeline construction</a></span><ul class="toc-item"><li><span><a href="#Pipeline-with-imblearn" data-toc-modified-id="Pipeline-with-imblearn-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pipeline with imblearn</a></span></li></ul></li><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>GridSearch CV</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Fitting" data-toc-modified-id="Fitting-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Fitting</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Model-score" data-toc-modified-id="Model-score-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Model score</a></span></li><li><span><a href="#Classification-report" data-toc-modified-id="Classification-report-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Classification report</a></span></li><li><span><a href="#ROC-curve" data-toc-modified-id="ROC-curve-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>ROC curve</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Confusion matrix</a></span></li></ul></li></ul></li><li><span><a href="#Hyperparameters-optimization" data-toc-modified-id="Hyperparameters-optimization-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Hyperparameters optimization</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>GridSearch CV</a></span></li><li><span><a href="#Best-model-scores" data-toc-modified-id="Best-model-scores-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Best model scores</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>SGD Classifier</a></span><ul class="toc-item"><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>GridSearch CV</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Decision Tree Classifier</a></span><ul class="toc-item"><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>GridSearch CV</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Random Forest Classifier</a></span><ul class="toc-item"><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>GridSearch CV</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#XGBoost-Classifier" data-toc-modified-id="XGBoost-Classifier-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>XGBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#Booster-=-gbtree" data-toc-modified-id="Booster-=-gbtree-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Booster = gbtree</a></span></li><li><span><a href="#GridSearchCV" data-toc-modified-id="GridSearchCV-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>GridSearchCV</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>Results</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction
#
# In this notebook, development of machine learning classification models will be reported
#
# ### Previously
#
# EDA was performed from a Kaggle kernel
# Pre-processing was performed from a Kaggle kernel
#
# ### Imports

# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd 

# File system manangement
#import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### Settings

# %%
# %config IPCompleter.greedy=True #Auto-completion
sns.set(style='white')
pd.options.display.max_colwidth = 90  # set column width to see all of it
pd.set_option('display.max_columns', 50) # display max. 50 columns
pd.set_option('display.max_rows', 100)  # display max. 100 rows

# %% [markdown]
# ### Read data

# %%
# List files available
print(os.listdir(r"C:\Users\I-NL\Documents\Projet7_OC"))
# Out:
# ['.git', '.ipynb_checkpoints', 'application_test.csv', 'application_train.csv', 'application_train_test.csv', 'bureau.csv', 'bureau_balance.csv', 'bureau_preprocessed.csv', 'credit_card_balance.csv', 'credit_card_balance_preprocessed.csv', 'HomeCredit_columns_description.csv', 'installments_payments.csv', 'install_payments_preprocessed.csv', 'lgbm_importances01.png', 'log_reg_baseline.csv', 'P7-eda-introduction.ipynb', 'P7_machine_learning.ipynb', 'POS_CASH_balance.csv', 'POS_CASH_balance_preprocessed.csv', 'preprocessed_data_p7.csv', 'preprocess_p7.txt', 'previous_application.csv', 'prev_appl_preprocessed.csv', 'Projet7_notebook_preprocessing.ipynb', 'random_forest_baseline.csv', 'random_forest_baseline_domain.csv', 'random_forest_baseline_engineered.csv', 'sample_submission.csv', 'submission_kernel02.csv']

# %%
data = pd.read_csv('preprocessed_data_p7.csv', index_col=2)
data = data.drop(columns=['Unnamed: 0', 'index'])
data.head()
# Out:
#             TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# SK_ID_CURR
# 100002         1.0            0             0                0             0
# 100003         0.0            1             0                1             0
# 100004         0.0            0             1                0             0
# 100006         0.0            1             0                0             0
# 100007         0.0            0             0                0             0
#
#             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# SK_ID_CURR
# 100002              202500.0    406597.5      24700.5         351000.0
# 100003              270000.0   1293502.5      35698.5        1129500.0
# 100004               67500.0    135000.0       6750.0         135000.0
# 100006              135000.0    312682.5      29686.5         297000.0
# 100007              121500.0    513000.0      21865.5         513000.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356251 entries, 100002 to 456250
# Columns: 796 entries, TARGET to CC_COUNT
# dtypes: float64(622), int64(174)
# memory usage: 2.1 GB

# %% [markdown]
# All the dataset is encoded in numerical values. Columns with a lot of NaN values will be deleted, and others will be imputed with median before machine learning.

# %% [markdown]
# ## Cleaning dataset
# Take care of NaN

# %%
print(data.isna().mean())
# Out:
# Unnamed: 0                                                               0.000000
# index                                                                    0.000000
# SK_ID_CURR                                                               0.000000
# TARGET                                                                   0.136825
# CODE_GENDER                                                              0.000000
# FLAG_OWN_CAR                                                             0.000000
# FLAG_OWN_REALTY                                                          0.000000
# CNT_CHILDREN                                                             0.000000
# AMT_INCOME_TOTAL                                                         0.000000
# AMT_CREDIT                                                               0.000000
# AMT_ANNUITY                                                              0.000101
# ...

# %%
data.drop(data.columns[data.isna().mean() > 0.7], axis=1, inplace=True)

# %%
print(data.isna().mean())
# Out:
# TARGET                                                                   0.136825
# CODE_GENDER                                                              0.000000
# FLAG_OWN_CAR                                                             0.000000
# FLAG_OWN_REALTY                                                          0.000000
# CNT_CHILDREN                                                             0.000000
# AMT_INCOME_TOTAL                                                         0.000000
# AMT_CREDIT                                                               0.000000
# AMT_ANNUITY                                                              0.000101
# AMT_GOODS_PRICE                                                          0.000780
# REGION_POPULATION_RELATIVE                                               0.000000
# DAYS_BIRTH                                                               0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356251 entries, 100002 to 456250
# Columns: 644 entries, TARGET to INSTAL_COUNT
# dtypes: float64(470), int64(174)
# memory usage: 1.7 GB

# %%
# Dealing with infinite values : replace with NaN
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Imputation
data.fillna(data.median(), inplace=True)
#data = SimpleImputer(strategy='median').fit_transform(data)

# %%
#Saving clean dataset
data.to_csv('p7_clean_dataset_for_ml.csv')

# %% [markdown]
# ### Preparation for machine learning

# %%
data = pd.read_csv('p7_clean_dataset_for_ml.csv')

X = data.drop(columns=['TARGET'])
y = data['TARGET']

print("X dimensions : ", X.shape)
print("y dimensions : ", y.shape)
# Out:
# X dimensions :  (356251, 644)
# y dimensions :  (356251,)

# %%
# Scaling data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ### Train set & test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=77)

# %% [markdown]
# ### Re-sampling train set data with SMOTE
#
# Synthetic Minority Oversampling Technique (SMOTE)
#
# This technique generates synthetic data for the minority class.
#
# SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority class and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point and its neighbors.
#
# SMOTE algorithm works in 4 simple steps:
#
# 1. Choose a minority class as the input vector
# 2. Find its k nearest neighbors (k_neighbors is specified as an argument in the ```SMOTE()``` function)
# 3. Choose one of these neighbors and place a synthetic point anywhere on the line joining the point under consideration and its chosen neighbor
# 4. Repeat the steps until data is balanced
#
# _Source:_ https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/

# %%
# import library
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(X_train, y_train)

print('Original dataset shape', X_train.shape, y_train.shape)
print('Resample dataset shape', x_smote.shape, y_smote.shape)
# Out:
# Original dataset shape (285000, 644) (285000,)
# Resample dataset shape (530398, 644) (530398,)

# %% [markdown]
# ## Baseline model : Dummy Classifier

# %% [markdown]
# ### Model

# %%
from sklearn.dummy import DummyClassifier
dummy_clf = DummyClassifier(strategy = 'stratified')
dummy_clf.fit(x_smote, y_smote)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14392/299079177.py in <module>
#       1 from sklearn.dummy import DummyClassifier
#       2 dummy_clf = DummyClassifier(strategy = 'stratified')
# ----> 3 dummy_clf.fit(x_smote, y_smote)
#
# NameError: name 'x_smote' is not defined

# %%
dummy_clf.predict(X_test)
# Out:
# array([1., 1., 1., ..., 1., 0., 0.])

# %%
dummy_clf.score(x_smote, y_smote)
# Out:
# 0.4995663633724109

# %%
dummy_clf.score(X_test, y_test)
# Out:
# 0.4987438772789154

# %%
y_pred = dummy_clf.predict(X)

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=y, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.50      0.65    331426
#          1.0       0.07      0.50      0.12     24825
#
#     accuracy                           0.50    356251
#    macro avg       0.50      0.50      0.39    356251
# weighted avg       0.87      0.50      0.62    356251

# %% [markdown]
# ### ROC AUC score
# #### Train score

# %%
from sklearn.metrics import roc_auc_score
y_score = dummy_clf.predict_proba(x_smote)[:, 1]
roc_auc_score(y_smote, y_score)
# Out:
# 0.4999453240773909

# %% [markdown]
# #### Test score

# %%
y_score_test = dummy_clf.predict_proba(X_test)[:, 1]
roc_auc_score(y_test, y_score_test)
# Out:
# 0.4980154298730702

# %% [markdown]
# ### ROC curve

# %%
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
fpr, tpr, thresholds = roc_curve(y, y_pred)
roc_auc = auc(fpr, tpr)
display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='Dummy Classifier estimator')
display.plot()
plt.title('ROC curve')
plt.show()

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = clf.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ## Classification models : first tests
#
# - Linear models : Linear SVC, Logistic Regression, Ridge Classifier CV
# - Non-linear models : SGDClassifier, KNeighborsClassifier, DecisionTreeClassifier
# - Ensemble methods : XGBoost, RandomForestClassifier

# %% [markdown]
# ### Quick evaluation function

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_auc_score, auc, roc_curve, RocCurveDisplay
from sklearn.metrics import confusion_matrix, classification_report

def classifier_quick_evaluation(clf, clf_name, X, y):
    
    """
    This function enables a quick test of a classification model, 
    without any preprocessing included, neither hyperparameter optimization.
    This function suppose that data are unbalanced, SMOTE is used.
    -------------------------------------------
    Arguments:
    clf : classification model
    clf_name : estimator name (str)
    X : dataframe or array of preprocessed_data_p7.csv data, excluding target
    y : dataframe or array of target variable
    --------------------------------------------
    Return: 
    classification report
    confusion matrix
    ROC AUC score
    ROC curve
    """
    
    #Train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=77)
    print('Dataset splitted in train set and test set')
    print('Train set:', X_train.shape, y_train.shape)
    print('Test set:', X_test.shape, y_test.shape)
    
    #Re-sample with smote
    smote = SMOTE()
    X_train, y_train = smote.fit_resample(X_train, y_train)  # fit predictor and target variable
    print('Resampling with SMOTE done')
    
    #Train classifier
    clf.fit(X_train, y_train)
    print('Classification model trained')
    
    #Train score vs test score
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    # ROC AUC score 
    y_score_train = clf.predict_proba(X_train)[:, 1]
    roc_train = roc_auc_score(y_train, y_score_train)
    y_score_test = clf.predict_proba(X_test)[:, 1]
    roc_test = roc_auc_score(y_test, y_score_test)
    
    #Make prediction
    y_pred = clf.predict(X)
                           
    #Report
    print('Model:', clf)
    print('Train score:', train_score) 
    print('Test_score:', test_score)
    print('ROC AUC train score:', roc_train)
    print('ROC AUC test score:', roc_test)
    print(classification_report(y_true=y, y_pred=y_pred))
    print('Confusion matrix\n', confusion_matrix(y_true=y, y_pred=y_pred))

    # Plot ROC curve
    fpr, tpr, thresholds = roc_curve(y, y_pred)
    roc_auc = auc(fpr, tpr)
    display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name=clf_name)
    display.plot()
    plt.title('ROC curve')
    plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=77)
classifier_quick_evaluation(clf,'Logistic Regression', X, y)
# Out:
# Dataset splitted in train set and test set
# Train set: (285000, 644) (285000,)
# Test set: (71251, 644) (71251,)
# Resampling with SMOTE done
# Classification model trained
# Model: LogisticRegression(random_state=77)
# Train score: 0.7489526732755403
# Test_score: 0.7238915945039368
# ROC AUC train score: 0.8223300329701815
# ROC AUC test score: 0.7616874519542369
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.83    331426
#          1.0       0.15      0.66      0.25     24825
#
#     accuracy                           0.72    356251
#    macro avg       0.56      0.70      0.54    356251
# weighted avg       0.91      0.72      0.79    356251
#
# [[241019  90407]
#  [  8350  16475]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11112/2158530781.py in <module>
# ...

# %% [markdown]
# ### SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='log_loss', random_state=77)  # Default : loss = 'hinge' i.e. using linear svm
classifier_quick_evaluation(clf, 'SGD Classifier', X, y)
# Out:
# Dataset splitted in train set and test set
# Train set: (285000, 644) (285000,)
# Test set: (71251, 644) (71251,)
# Resampling with SMOTE done
# Classification model trained
# Model: SGDClassifier(loss='log_loss', random_state=77)
# Train score: 0.7413923129423565
# Test_score: 0.7273582125163156
# ROC AUC train score: 0.8146142252918551
# ROC AUC test score: 0.7576621390923459
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.83    331426
#          1.0       0.15      0.65      0.25     24825
#
#     accuracy                           0.72    356251
#    macro avg       0.56      0.69      0.54    356251
# weighted avg       0.91      0.72      0.79    356251
#
# [[242117  89309]
#  [  8667  16158]]

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=77)  # Default parameters
classifier_quick_evaluation(clf, 'Decision Tree Classifier', X, y)
# Out:
# Dataset splitted in train set and test set
# Train set: (285000, 644) (285000,)
# Test set: (71251, 644) (71251,)
# Resampling with SMOTE done
# Classification model trained
# Model: DecisionTreeClassifier(random_state=77)
# Train score: 1.0
# Test_score: 0.8538125780690797
# ROC AUC train score: 1.0
# ROC AUC test score: 0.535720676888763
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98    331426
#          1.0       0.77      0.83      0.80     24825
#
#     accuracy                           0.97    356251
#    macro avg       0.88      0.91      0.89    356251
# weighted avg       0.97      0.97      0.97    356251
#
# [[325203   6223]
#  [  4193  20632]]

# %% [markdown]
#  ### XGBoost Classifier

# %%
import xgboost as xgb
clf = xgb.XGBClassifier(random_state=77)
classifier_quick_evaluation(clf, 'XGBoost Classifier', X, y)
# Out:
# Dataset splitted in train set and test set
# Train set: (285000, 644) (285000,)
# Test set: (71251, 644) (71251,)
# Resampling with SMOTE done
# Classification model trained
# Model: XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=77,
#               reg_alpha=0, reg_lambda=1, ...)
# Train score: 0.9657351649138949
# Test_score: 0.9290816970989881
# ...

# %% [markdown]
#  ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=77)
classifier_quick_evaluation(clf, 'Random Forest Classifier', X, y)
# Out:
# Dataset splitted in train set and test set
# Train set: (285000, 644) (285000,)
# Test set: (71251, 644) (71251,)
# Resampling with SMOTE done
# Classification model trained
# Model: RandomForestClassifier(random_state=77)
# Train score: 1.0
# Test_score: 0.9285062665787147
# ROC AUC train score: 1.0
# ROC AUC test score: 0.708173688216623
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99    331426
#          1.0       0.99      0.80      0.89     24825
#
#     accuracy                           0.99    356251
#    macro avg       0.99      0.90      0.94    356251
# weighted avg       0.99      0.99      0.98    356251
#
# [[331300    126]
#  [  4968  19857]]

# %% [markdown]
# ## Pipeline construction
# ### Pipeline with imblearn

# %%
from imblearn.pipeline import Pipeline 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline 

def make_model(clf):
    model = Pipeline([
            ('scaler', StandardScaler()),
            ('sampling', SMOTE(random_state=77)),
            ('classification', clf)
        ])
    return model

# %%
from sklearn.dummy import DummyClassifier
random_state = 77
clf = DummyClassifier(strategy = 'stratified', random_state=random_state)
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  DummyClassifier(random_state=77, strategy='stratified'))])

# %% [markdown]
# ## GridSearch CV

# %% [markdown]
# ### Parameters

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'scaler', 'sampling', 'classification', 'scaler__copy', 'scaler__with_mean', 'scaler__with_std', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__constant', 'classification__random_state', 'classification__strategy'])

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5, 7] ,
             }

# %% [markdown]
# ### Fitting

# %%
grid = GridSearchCV(model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1, refit='roc_auc')
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('sampling', SMOTE(random_state=77)),
#                                        ('classification',
#                                         DummyClassifier(random_state=77,
#                                                         strategy='stratified'))]),
#              param_grid={'sampling__k_neighbors': [3, 5, 7]}, refit='roc_auc',
#              scoring='roc_auc', verbose=1)

# %% [markdown]
# ### Results

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([39.68325667, 42.99837189, 45.55501652]),
#  'std_fit_time': array([1.94966138, 3.26747744, 2.02679308]),
#  'mean_score_time': array([1.58299937, 1.66515393, 1.6484447 ]),
#  'std_score_time': array([0.135026 , 0.1743997, 0.1112111]),
#  'param_sampling__k_neighbors': masked_array(data=[3, 5, 7],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'sampling__k_neighbors': 3},
#   {'sampling__k_neighbors': 5},
#   {'sampling__k_neighbors': 7}],
#  'split0_test_score': array([0.49940182, 0.49940182, 0.49940182]),
#  'split1_test_score': array([0.49465269, 0.49465269, 0.49465269]),
#  'split2_test_score': array([0.49655234, 0.49655234, 0.49655234]),
#  'split3_test_score': array([0.5010301, 0.5010301, 0.5010301]),
#  'split4_test_score': array([0.49580657, 0.49580657, 0.49580657]),
#  'mean_test_score': array([0.49748871, 0.49748871, 0.49748871]),
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.49748870616915974
# {'sampling__k_neighbors': 3}

# %% [markdown]
# For multi-metric evaluation, the scores for all the scorers are available in the cv_results_ dict at the keys ending with that scorer’s name ```('_<scorer_name>')``` instead of ```'_score'``` shown above. ```(‘split0_test_precision’, ‘mean_train_precision’ etc.)```

# %% [markdown]
# #### Model score

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.49714389973474055

# %% [markdown]
# #### Classification report

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.50      0.65     66227
#          1.0       0.07      0.50      0.12      5024
#
#     accuracy                           0.50     71251
#    macro avg       0.50      0.50      0.39     71251
# weighted avg       0.87      0.50      0.61     71251

# %% [markdown]
# #### ROC curve

# %%
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='Dummy Classifier estimator')
display.plot()
plt.title('ROC curve')
plt.show()

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=grid.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=grid.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ## Hyperparameters optimization
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
random_state = 77
clf = LogisticRegression(random_state=random_state, verbose=1)
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  LogisticRegression(random_state=77, verbose=1))])

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'sampling', 'classification', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__C', 'classification__class_weight', 'classification__dual', 'classification__fit_intercept', 'classification__intercept_scaling', 'classification__l1_ratio', 'classification__max_iter', 'classification__multi_class', 'classification__n_jobs', 'classification__penalty', 'classification__random_state', 'classification__solver', 'classification__tol', 'classification__verbose', 'classification__warm_start'])

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5, 7] ,
    'classification__C' : [0.1, 0.5, 1.0, 1.5]
             }

# %% [markdown]
# #### GridSearch CV

# %%
grid = GridSearchCV(model, param_grid=param_grid, cv=3, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   19.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   19.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   19.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   21.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.7s finished
# ...

# %% [markdown]
# #### Best model scores

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.7231298245614034
# {'classification__C': 0.1, 'sampling__k_neighbors': 3}

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   30.7s finished
# 0.7242845714446113

# %% [markdown]
# #### Results

# %%
def clf_results(clf_name, clf, X, y, X_train, y_train, X_test, y_test):
    
    """
    This function displays all results from a trained classification model
    Inputs : 
    - clf_name : str, name of the model
    - clf : model trained
    - X, y : data and target (dataframe or array)
    - X_train, y_train, X_test, y_test : data and target after train_test_split (dataframe or array)
    
    Outputs : 
    - train score
    - test score
    - classification report
    - confusion matrix
    - ROC AUC score
    - ROC curve
    """
    
    #Train score vs test score
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    # ROC AUC score 
    y_score_train = clf.predict_proba(X_train)[:, 1]
    roc_train = roc_auc_score(y_train, y_score_train)
    y_score_test = clf.predict_proba(X_test)[:, 1]
    roc_test = roc_auc_score(y_test, y_score_test)
    
    #Make prediction
    y_pred = clf.predict(X)
                           
    #Report
    print('Model:', clf)
    print('Train score:', train_score) 
    print('Test_score:', test_score)
    print('ROC AUC train score:', roc_train)
    print('ROC AUC test score:', roc_test)
    print(classification_report(y_true=y, y_pred=y_pred))
    print('Confusion matrix\n', confusion_matrix(y_true=y, y_pred=y_pred))

    # Plot ROC curve
    fpr, tpr, thresholds = roc_curve(y, y_pred)
    roc_auc = auc(fpr, tpr)
    display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name=clf_name)
    display.plot()
    plt.title('ROC curve')
    plt.show()

# %%
clf_results('Logistic Regression', model, X, y, X_train, y_train, X_test, y_test)
# Out:
# Model: Pipeline(steps=[('sampling', SMOTE(k_neighbors=3, random_state=77)),
#                 ('classification',
#                  LogisticRegression(C=0.1, random_state=77, verbose=1))])
# Train score: 0.722319298245614
# Test_score: 0.7242845714446113
# ROC AUC train score: 0.7638738889863028
# ROC AUC test score: 0.7617478592976732
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.83    331426
#          1.0       0.15      0.66      0.25     24825
#
#     accuracy                           0.72    356251
#    macro avg       0.56      0.69      0.54    356251
# weighted avg       0.91      0.72      0.79    356251
#
# Confusion matrix
#  [[241020  90406]
#  [  8378  16447]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(X)
cm = confusion_matrix(y, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ### SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
random_state = 77
clf = SGDClassifier(loss='log_loss', random_state=random_state, verbose=1)
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  SGDClassifier(loss='log_loss', random_state=77, verbose=1))])

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'sampling', 'classification', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__alpha', 'classification__average', 'classification__class_weight', 'classification__early_stopping', 'classification__epsilon', 'classification__eta0', 'classification__fit_intercept', 'classification__l1_ratio', 'classification__learning_rate', 'classification__loss', 'classification__max_iter', 'classification__n_iter_no_change', 'classification__n_jobs', 'classification__penalty', 'classification__power_t', 'classification__random_state', 'classification__shuffle', 'classification__tol', 'classification__validation_fraction', 'classification__verbose', 'classification__warm_start'])

# %% [markdown]
# #### GridSearch CV

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5, 7] ,
    'classification__alpha' : [0.0001, 0.0005 , 0.001] ,
    'classification__penalty': ['l1', 'l2'],
    'classification__loss' : ['hinge', 'log_loss']
}

# %%
grid = GridSearchCV(model, param_grid=param_grid, cv=5, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# -- Epoch 1
# Norm: 1849.33, NNZs: 239, Bias: -13.358525, T: 424318, Avg. loss: 19.889644
# Total training time: 3.51 seconds.
# -- Epoch 2
# Norm: 1838.11, NNZs: 238, Bias: -12.698730, T: 848636, Avg. loss: 5.259014
# Total training time: 7.32 seconds.
# -- Epoch 3
# Norm: 1830.66, NNZs: 252, Bias: -12.489883, T: 1272954, Avg. loss: 4.831378
# Total training time: 10.96 seconds.
# -- Epoch 4
# Norm: 1825.43, NNZs: 279, Bias: -12.873798, T: 1697272, Avg. loss: 4.648084
# Total training time: 14.58 seconds.
# -- Epoch 5
# Norm: 1821.36, NNZs: 280, Bias: -12.784457, T: 2121590, Avg. loss: 4.522672
# Total training time: 18.16 seconds.
# -- Epoch 6
# Norm: 1817.94, NNZs: 283, Bias: -12.908902, T: 2545908, Avg. loss: 4.427871
# Total training time: 21.79 seconds.
# -- Epoch 7
# Norm: 1815.05, NNZs: 287, Bias: -12.890719, T: 2970226, Avg. loss: 4.357551
# Total training time: 25.39 seconds.
# -- Epoch 8
# ...

# %% [markdown]
# ###### Model scores

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.7212315789473684
# {'classification__alpha': 0.0005, 'classification__loss': 'log_loss', 'classification__penalty': 'l2', 'sampling__k_neighbors': 3}

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# -- Epoch 1
# Norm: 4.77, NNZs: 625, Bias: -1.251076, T: 530398, Avg. loss: 2.493979
# Total training time: 1.19 seconds.
# -- Epoch 2
# Norm: 3.32, NNZs: 625, Bias: -0.888338, T: 1060796, Avg. loss: 0.610470
# Total training time: 2.33 seconds.
# -- Epoch 3
# Norm: 2.85, NNZs: 625, Bias: -0.906433, T: 1591194, Avg. loss: 0.566365
# Total training time: 3.43 seconds.
# -- Epoch 4
# Norm: 2.67, NNZs: 625, Bias: -0.897743, T: 2121592, Avg. loss: 0.549017
# Total training time: 4.44 seconds.
# -- Epoch 5
# Norm: 2.63, NNZs: 625, Bias: -0.853952, T: 2651990, Avg. loss: 0.541662
# Total training time: 5.48 seconds.
# -- Epoch 6
# Norm: 2.57, NNZs: 625, Bias: -0.828250, T: 3182388, Avg. loss: 0.536541
# Total training time: 6.58 seconds.
# -- Epoch 7
# Norm: 2.55, NNZs: 625, Bias: -0.828041, T: 3712786, Avg. loss: 0.533254
# Total training time: 7.76 seconds.
# -- Epoch 8
# Norm: 2.53, NNZs: 625, Bias: -0.841604, T: 4243184, Avg. loss: 0.530551
# Total training time: 8.92 seconds.
# ...

# %% [markdown]
# #### Results

# %%
clf_results('SGD Classifier', model, X, y, X_train, y_train, X_test, y_test)
# Out:
# Model: Pipeline(steps=[('sampling', SMOTE(k_neighbors=3, random_state=77)),
#                 ('classification',
#                  SGDClassifier(alpha=0.0005, loss='log_loss', random_state=77,
#                                verbose=1))])
# Train score: 0.7148912280701755
# Test_score: 0.7160320556904465
# ROC AUC train score: 0.7596307203598684
# ROC AUC test score: 0.7586957361185553
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.72      0.82    331426
#          1.0       0.15      0.67      0.25     24825
#
#     accuracy                           0.72    356251
#    macro avg       0.56      0.69      0.53    356251
# weighted avg       0.91      0.72      0.78    356251
#
# Confusion matrix
#  [[238243  93183]
#  [  8306  16519]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(X)
cm = confusion_matrix(y, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=77)  # Default parameters
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('sampling', SMOTE(random_state=77)),
#                 ('classification', DecisionTreeClassifier(random_state=77))])

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'sampling', 'classification', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__ccp_alpha', 'classification__class_weight', 'classification__criterion', 'classification__max_depth', 'classification__max_features', 'classification__max_leaf_nodes', 'classification__min_impurity_decrease', 'classification__min_samples_leaf', 'classification__min_samples_split', 'classification__min_weight_fraction_leaf', 'classification__random_state', 'classification__splitter'])

# %% [markdown]
# #### GridSearch CV

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5, 7], 
    'classification__max_depth' : [3, 5, 7, 9],     
}

# %%
grid = GridSearchCV(model, param_grid=param_grid, cv=3, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('sampling', SMOTE(random_state=77)),
#                                        ('classification',
#                                         DecisionTreeClassifier(random_state=77))]),
#              param_grid={'classification__max_depth': [3, 5, 7, 9],
#                          'sampling__k_neighbors': [3, 5, 7]},
#              verbose=1)

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8899438596491228
# {'classification__max_depth': 9, 'sampling__k_neighbors': 5}

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9043662545087087

# %% [markdown]
# #### Results

# %%
clf_results('Decision Tree Classifier', model, X, y, X_train, y_train, X_test, y_test)
# Out:
# Model: Pipeline(steps=[('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  DecisionTreeClassifier(max_depth=9, random_state=77))])
# Train score: 0.9053754385964913
# Test_score: 0.9043662545087087
# ROC AUC train score: 0.6590636301636694
# ROC AUC test score: 0.64529897274035
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95    331426
#          1.0       0.16      0.09      0.11     24825
#
#     accuracy                           0.91    356251
#    macro avg       0.55      0.53      0.53    356251
# weighted avg       0.88      0.91      0.89    356251
#
# Confusion matrix
#  [[320305  11121]
#  [ 22661   2164]]

# %%
#from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(X)
cm = confusion_matrix(y, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=77,
                            criterion='gini',
                            verbose=1)
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  RandomForestClassifier(random_state=77, verbose=1))])

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'scaler', 'sampling', 'classification', 'scaler__copy', 'scaler__with_mean', 'scaler__with_std', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__bootstrap', 'classification__ccp_alpha', 'classification__class_weight', 'classification__criterion', 'classification__max_depth', 'classification__max_features', 'classification__max_leaf_nodes', 'classification__max_samples', 'classification__min_impurity_decrease', 'classification__min_samples_leaf', 'classification__min_samples_split', 'classification__min_weight_fraction_leaf', 'classification__n_estimators', 'classification__n_jobs', 'classification__oob_score', 'classification__random_state', 'classification__verbose', 'classification__warm_start'])

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5],
    'classification__max_depth' : [5, 9],
    'classification__min_samples_leaf' : [2, 15],
    'classification__n_estimators' : [50, 100]
}

# %% [markdown]
# min_samples_splitint or float, default=2
#
#     The minimum number of samples required to split an internal node:
#
#         If int, then consider min_samples_split as the minimum number.
#
#         If float, then min_samples_split is a fraction and ceil(min_samples_split * n_samples) are the minimum number of samples for each split.

# %% [markdown]
# #### GridSearch CV

# %%
grid = GridSearchCV(model, param_grid=param_grid, cv=3, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.8min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.8min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.7min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.7s finished
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8583789473684211
# {'classification__max_depth': 9, 'classification__min_samples_leaf': 15, 'classification__n_estimators': 100, 'sampling__k_neighbors': 3}

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed: 14.0min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.8s finished
# 0.8507249021066371

# %% [markdown]
# #### Results

# %%
clf_results('Random Forest Classifier', model, X, y, X_train, y_train, X_test, y_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    7.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    8.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   10.4s finished
# Model: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('sampling', SMOTE(k_neighbors=3, random_state=77)),
#                 ('classification',
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(X)
cm = confusion_matrix(y, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    9.8s finished

# %% [markdown]
# ### XGBoost Classifier
# #### Booster = gbtree

# %% [markdown]
# Parameters to set afterwards if possible !
#
# grow_policy [default= depthwise]
#
#     Controls a way new nodes are added to the tree.
#
#     Currently supported only if tree_method is set to hist, approx or gpu_hist.
#
#     Choices: depthwise, lossguide
#
#         depthwise: split at nodes closest to the root.
#
#         lossguide: split at nodes with highest loss change.

# %%
import xgboost as xgb
clf = xgb.XGBClassifier(random_state=77, 
                        booster='gbtree', 
                        objective= 'binary:logistic', 
                        eval_metric = 'auc', 
                        verbosity=1)  # Get info during optimization
model = make_model(clf)
model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('sampling', SMOTE(random_state=77)),
#                 ('classification',
#                  XGBClassifier(base_score=None, booster='gbtree',
#                                callbacks=None, colsample_bylevel=None,
#                                colsample_bynode=None, colsample_bytree=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='auc',
#                                gamma=None, gpu_id=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=None,
#                                max_leaves=None, min_child_weight=None,
# ...

# %%
model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'scaler', 'sampling', 'classification', 'scaler__copy', 'scaler__with_mean', 'scaler__with_std', 'sampling__k_neighbors', 'sampling__n_jobs', 'sampling__random_state', 'sampling__sampling_strategy', 'classification__objective', 'classification__use_label_encoder', 'classification__base_score', 'classification__booster', 'classification__callbacks', 'classification__colsample_bylevel', 'classification__colsample_bynode', 'classification__colsample_bytree', 'classification__early_stopping_rounds', 'classification__enable_categorical', 'classification__eval_metric', 'classification__gamma', 'classification__gpu_id', 'classification__grow_policy', 'classification__importance_type', 'classification__interaction_constraints', 'classification__learning_rate', 'classification__max_bin', 'classification__max_cat_to_onehot', 'classification__max_delta_step', 'classification__max_depth', 'classification__max_leaves', 'classification__min_child_weight', '
# ...

# %% [markdown]
# #### GridSearchCV

# %%
param_grid = {
    'sampling__k_neighbors' : [3, 5],
    'classification__gamma' : [0, 0.5], 
    'classification__learning_rate' : [0.1, 0.3], 
    'classification__max_depth' : [3, 6], 
    'classification__n_estimators' : [50, 100] 
}

# %%
#from sklearn.model_selection import RandomizedSearchCV

# %%
grid = GridSearchCV(model, param_grid, scoring='roc_auc', cv=3, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18188/103350959.py in <module>
#       1 grid = GridSearchCV(model, param_grid, scoring='roc_auc', cv=3, verbose=1)
# ----> 2 grid.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1373     def _run_search(self, evaluate_candidates):
#    1374         """Search all candidates in param_grid"""
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)

# %%
model = grid.best_estimator_
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %% [markdown]
# #### Results

# %%
clf_results('XGBoost', model, X, y, X_train, y_train, X_test, y_test)
